# %% [markdown]
# # Importing the necessary information including title and text of the given articles URL ID

# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import pandas as pd

# Load the input file
df = pd.read_excel('Input.xlsx')

# Define the directory where the extracted text files will be stored
directory = 'extracted_text'

# Create the directory if it does not exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Loop through each row in the dataframe
for index, row in df.iterrows():
    try:
        # Get the URL and URL_ID for the current row
        url = row['URL']
        url_id = row['URL_ID']
        
        # Send a request to the URL and get the HTML response
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the title and text
        title = soup.find('title').text
        text = ' '.join(map(lambda p: p.text, soup.find_all('p')))

        # Remove any unwanted characters from the title and text
        title = re.sub(r'[^\x00-\x7F]+',' ', title)
        text = re.sub(r'[^\x00-\x7F]+',' ', text)

        # Concatenate the title and text
        content = title + '\n' + text

        # Write the extracted text to a file
        with open(f'{directory}/{url_id}.txt', 'w', encoding='utf-8') as f:
            f.write(content)
    except:
        # If there is any error, print a message
        print(f'Error extracting text from URL_ID: {url_id}')
    
    print("URL", index+1, "Scanned")

print('Text extraction completed!')
# Out:
# URL 1 Scanned
# URL 2 Scanned
# URL 3 Scanned
# URL 4 Scanned
# URL 5 Scanned
# URL 6 Scanned
# URL 7 Scanned
# URL 8 Scanned
# URL 9 Scanned
# URL 10 Scanned
# URL 11 Scanned
# URL 12 Scanned
# URL 13 Scanned
# URL 14 Scanned
# URL 15 Scanned
# URL 16 Scanned
# URL 17 Scanned
# URL 18 Scanned
# URL 19 Scanned
# URL 20 Scanned
# URL 21 Scanned
# URL 22 Scanned
# URL 23 Scanned
# URL 24 Scanned
# URL 25 Scanned
# URL 26 Scanned
# URL 27 Scanned
# URL 28 Scanned
# URL 29 Scanned
# URL 30 Scanned
# URL 31 Scanned
# URL 32 Scanned
# URL 33 Scanned
# URL 34 Scanned
# URL 35 Scanned
# URL 36 Scanned
# URL 37 Scanned
# URL 38 Scanned
# URL 39 Scanned
# URL 40 Scanned
# URL 41 Scanned
# URL 42 Scanned
# URL 43 Scanned
# URL 44 Scanned
# URL 45 Scanned
# URL 46 Scanned
# URL 47 Scanned
# URL 48 Scanned
# URL 49 Scanned
# URL 50 Scanned
# URL 51 Scanned
# URL 52 Scanned
# URL 53 Scanned
# URL 54 Scanned
# URL 55 Scanned
# URL 56 Scanned
# URL 57 Scanned
# URL 58 Scanned
# URL 59 Scanned
# URL 60 Scanned
# URL 61 Scanned
# URL 62 Scanned
# URL 63 Scanned
# URL 64 Scanned
# URL 65 Scanned
# URL 66 Scanned
# URL 67 Scanned
# URL 68 Scanned
# URL 69 Scanned
# URL 70 Scanned
# URL 71 Scanned
# URL 72 Scanned
# URL 73 Scanned
# URL 74 Scanned
# URL 75 Scanned
# URL 76 Scanned
# URL 77 Scanned
# URL 78 Scanned
# URL 79 Scanned
# URL 80 Scanned
# URL 81 Scanned
# URL 82 Scanned
# URL 83 Scanned
# URL 84 Scanned
# URL 85 Scanned
# URL 86 Scanned
# URL 87 Scanned
# URL 88 Scanned
# URL 89 Scanned
# URL 90 Scanned
# URL 91 Scanned
# URL 92 Scanned
# URL 93 Scanned
# URL 94 Scanned
# URL 95 Scanned
# URL 96 Scanned
# URL 97 Scanned
# URL 98 Scanned
# URL 99 Scanned
# URL 100 Scanned
# URL 101 Scanned
# URL 102 Scanned
# URL 103 Scanned
# URL 104 Scanned
# URL 105 Scanned
# URL 106 Scanned
# URL 107 Scanned
# URL 108 Scanned
# URL 109 Scanned
# URL 110 Scanned
# URL 111 Scanned
# URL 112 Scanned
# URL 113 Scanned
# URL 114 Scanned
# Text extraction completed!

# %% [markdown]
# # To know if the files are imported properly and check the names

# %%
import os

folder_path = path = r"C:\Users\Gaurav\Data Science - Analysis\BlackCoffr Internship\extracted_text"

files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

files.sort(key=lambda x: int(x.split('.')[0]))

print(files)

# To read the files
"""for file in files:
    # read the file
    with open(os.path.join(folder_path, file), 'r') as f:
        # do your processing here
        text = f.read()
        print(text)"""
# Out:
# ['37.txt', '38.txt', '39.txt', '40.txt', '41.txt', '42.txt', '43.txt', '44.txt', '45.txt', '46.txt', '47.txt', '48.txt', '49.txt', '50.txt', '51.txt', '52.txt', '53.txt', '54.txt', '55.txt', '56.txt', '57.txt', '58.txt', '59.txt', '60.txt', '61.txt', '62.txt', '63.txt', '64.txt', '65.txt', '66.txt', '67.txt', '68.txt', '69.txt', '70.txt', '71.txt', '72.txt', '73.txt', '74.txt', '75.txt', '76.txt', '77.txt', '78.txt', '79.txt', '80.txt', '81.txt', '82.txt', '83.txt', '84.txt', '85.txt', '86.txt', '87.txt', '88.txt', '89.txt', '90.txt', '91.txt', '92.txt', '93.txt', '94.txt', '95.txt', '96.txt', '97.txt', '98.txt', '99.txt', '100.txt', '101.txt', '102.txt', '103.txt', '104.txt', '105.txt', '106.txt', '107.txt', '108.txt', '109.txt', '110.txt', '111.txt', '112.txt', '113.txt', '114.txt', '115.txt', '116.txt', '117.txt', '118.txt', '119.txt', '120.txt', '121.txt', '122.txt', '123.txt', '124.txt', '125.txt', '126.txt', '127.txt', '128.txt', '129.txt', '130.txt', '131.txt', '132.txt', '133.txt', '134.txt', '135.txt', '136.txt', '137.txt', '138.txt', '139.txt', '140.txt', '141.txt', '142.txt', '143.txt', '144.txt', '145.txt', '146.txt', '147.txt', '148.txt', '149.txt', '150.txt']
# "for file in files:\n    # read the file\n    with open(os.path.join(folder_path, file), 'r') as f:\n        # do your processing here\n        text = f.read()\n        print(text)"

# %% [markdown]
# # List of all the stopwords mentioned in the mutliple text files converted into one list named stopwords

# %%
import os

# Define the path to the stopwords folder
stopwords_folder_path = "StopWords/"

# Get a list of all the stopword files in the folder
stopword_files = [file for file in os.listdir(stopwords_folder_path) if file.endswith(".txt")]

# Initialize an empty list to store the stopwords
stopwords = []

# Loop through each stopword file
for stopword_file in stopword_files:
    # Open the stopword file
    with open(os.path.join(stopwords_folder_path, stopword_file), 'r') as f:
        # Read the contents of the file
        contents = f.read()
        
        # Split the contents into words
        words = contents.split()
        
        # Add the words to the stopwords list
        stopwords.extend(words)

# Remove duplicates from the stopwords list
stopwords_list = list(set(stopwords))

print(stopwords_list)
# Out:
# ['MCCUTCHEN', 'COLWELL', 'JANE', 'ZANDRA', 'DEAS', 'MANZO', 'MILES', 'RINALDI', 'BILODEAU', 'RASCON', 'VASHTI', 'here', 'GILLESPIE', 'HATTON', 'HEREFORD', 'LISSA', 'DORTHA', 'DENMARK', 'CARLOTTA', 'DENNING', 'MADALYN', 'GLADIS', 'SHERIE', 'TANAKA', 'HALLMAN', 'GREENLEAF', 'DURKEE', 'WILBANKS', 'OTTEN', 'PING', 'TINKER', 'MERRY', 'HUDGINS', 'quite', 'MARCELLA', 'LACOMBE', 'CASKEY', 'YOUNT', 'DIONE', 'CARA', 'MAPLES', 'MCNEILL', 'DOAN', 'JUSTINA', 'TIA', 'ARMANDA', 'STEPP', 'ALESIA', 'ODOM', 'SPELL', 'relatively', 'KEMPF', 'GRAY', 'DICKEY', 'MOZELL', 'JOHNATHON', 'LORILEE', 'DOTTIE', 'HILARIO', 'inward', 'HILDEBRANDT', 'ENRIQUE', 'ROMA', 'KEYES', 'hereafter', 'ECHEVARRIA', 'URIBE', 'BUTTS', 'DAGGETT', 'DEENA', 'MEMPHIS', 'MORRIS', 'LLAMAS', 'HARDEMAN', 'TRAVERS', 'OSVALDO', 'HARDEE', 'DULCE', 'CLEMENTS', 'HAVEN', 'MATHEWSON', 'AGOSTO', 'MULL', 'MONIZ', 'GRABOWSKI', 'NAVE', 'SPILLMAN', 'ALLENA', 'OLIVEIRA', 'COATS', 'MARNI', 'BALLINGER', 'PRITCHARD', 'SHEPARD', 'associated', 'RIDER', 'MUIR', 'ALECIA', 'GARVEY', 'SCALF', 'TEODORO', 'ELVIS', 'STACEE', 'NGULTRUM', 'SAYLES', 'BRAVO', 'ALBERS', 'STATEN', 'ODUM', 'PENNIE', 'BLONDELL', 'ATKINS', 'MARLIN', 'MUMFORD', 'SHANNON', 'ZONA', 'BRAMLETT', 'HOFF', 'thoroughly', 'GAINER', 'PADILLA', 'KRYSTEN', 'okay', 'COMEAU', 'well', 'THROWER', 'FAUSTINO', 'KILE', 'MAR', 'THU', 'LEMAY', 'FRITH', 'SIXTH', 'FRAME', 'LOUVENIA', 'SAIN', 'HOUSE', 'LARKINS', 'FLORENCIA', 'RINGER', 'KEVEN', 'SCHELL', 'MCDAVID', 'ROXANNE', 'BATSON', 'GAYLENE', 'SITES', 'his', 'ARROYO', 'OVERTON', 'TIM', 'ADRIENNE', 'VERONIQUE', 'SOLIS', 'ARACELY', 'ROZIER', 'PAUL', 'GHISLAINE', 'HIGHSMITH', 'DONITA', 'SALAS', 'ELWANDA', 'MONTY', 'JOSIE', 'SOTELO', 'JACQUE', 'KLINE', 'MARX', 'RENFROW', 'Vanuatu', 'eg', 'WATKINS', 'LOYD', 'REDDEN', 'MANDY', 'VASILIKI', 'TO', 'DICARLO', 'GILLARD', 'BRANN', 'HOPSON', 'RIDEOUT', 'JACINDA', 'selves', 'LECIA', 'ROOKER', 'CLEO', 'GLINDA', 'LACHELLE', 'SWINNEY', 'ARMSTEAD', 'VENUS', 'BULA', 'SOARES', 'ELIZ', 'LYNELL', 'MIA', 'BURKHARDT', 'MERCHANT', 'LEDEZMA', 'HECKER', 'JOYE', 'COTTINGHAM', 'TENNEY', 'LUCIENNE', 'FEENEY', 'CUNNINGHAM', 'ENEDINA', 'HOKE', 'CIARA', 'ALMARAZ', 'NICK', 'LAVONIA', 'LEONARD', "they'll", 'LEVERETT', 'SCHULTE', 'BRUNER', 'COUNCIL', 'JENSON', 'MILEY', 'DELICIA', 'MARTEL', 'ESTRADA', 'SPAIN', 'CARYL', 'PREECE', 'GLENDORA', 'PHYLISS', 'ISELA', 'ELLIS', 'AVALOS', 'MCIVER', 'PASTY', 'BETANCOURT', 'TWELVE', 'LINO', 'RANDAZZO', 'SHON', 'TREJO', 'merely', 'VETA', 'LOWREY', 'BONNETT', 'LOUDERMILK', 'ARLINDA', 'DODD', 'MCVEY', 'JAMA', 'HAUG', 'CHERLY', 'EAGAN', 'DUQUETTE', 'MERLE', 'BEDWELL', 'HUGO', 'LAVINIA', 'KIMBERLI', 'EDYTH', 'CORDOVA', 'CECILIA', 'ILLINOIS', 'SOUTHEAST', 'SANDSTROM', 'CINTHIA', 'TAMALA', 'HOLLAR', 'GOBER', 'LINDGREN', 'XIAO', 'FENNELL', 'seeing', 'GILREATH', 'THAYER', 'RIVERA', 'LAVERNA', 'LEONIE', 'RHOADES', 'COMEAUX', 'NATASHIA', 'COLLADO', 'BUZZELL', 'DUNSTON', 'KONG', 'FRAWLEY', 'MARC', 'ANNIE', 'CONYERS', 'SHARON', 'BROCKMAN', 'KIMIKO', 'downwards', 'TRINH', 'THEODORE', 'GARRETT', 'DODGE', 'BEFORE', 'NICKOLAS', 'BRUNILDA', 'DREHER', 'IDA', 'OLIVE', 'SILVIA', 'ETTIE', 'PEGUES', 'PEAK', 'HYDE', 'LOFTUS', 'PETERSON', 'SARTIN', 'SHERI', 'TENNYSON', 'SEALS', 'JARAMILLO', 'HUMES', 'CHAFFEE', 'RIVERS', 'OLIVERA', 'Honduras', 'CURTIS', 'DORATHY', 'SHIPP', 'EIGHTY', 'MAC', 'try', 'JAMILA', 'JENKS', 'DOLL', 'BARNARD', 'OGLESBY', 'seven', 'RACHEAL', 'EVAN', 'VU', 'FARRINGTON', 'LULA', 'KITE', 'SHALA', 'entirely', 'SHAVONDA', 'LINNEA', 'NANCE', 'WILLS', 'GWENDA', 'CARRANZA', 'EICHER', 'DEBRAH', 'KATELIN', 'Botswana', 'MULLEN', 'WARFIELD', 'MEDLOCK', 'RUSSEL', 'MCKIBBEN', 'soon', 'ATWELL', 'DOBSON', 'CHASTITY', 'ALBANESE', 'ROD', 'SHAKITA', 'SMILEY', 'TYNER', 'LUGO', 'RYALS', 'VON', 'SUSANNAH', 'BURBANK', 'sometimes', 'DEBI', 'ERICKA', 'ATHERTON', 'TANIKA', 'JACQULYN', 'MCCORKLE', 'ZEPEDA', 'CORAL', 'DEES', 'STAMM', 'ARACELI', 'DAUGHTRY', 'PARROTT', 'RUPEE', "they'd", 'WORLEY', 'DICKENS', 'THERSA', 'HAM', 'MARISA', 'HEDRICK', 'DEERING', 'LAKEISHA', 'TAMISHA', 'FR ...

# %% [markdown]
# # Master Dictionary with keys as positive and negative and the respective words that were mentioned in the text file

# %%
# Define the positive and negative words lists
positive_words = []
negative_words = []

with open("MasterDictionary/positive-words.txt", "r") as file:
    positive_words = [word.strip() for word in file.readlines() if word.strip().lower() not in stopwords_list]

with open("MasterDictionary/negative-words.txt", "r") as file:
    negative_words = [word.strip() for word in file.readlines() if word.strip().lower() not in stopwords_list]

# Define the master dictionary
master_dict = {"positive": positive_words, "negative": negative_words}

print(master_dict)
# Out:
# {'positive': ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation', 'accolade', 'accolades', 'accommodative', 'accomodative', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', '
arity', 'classic', 'classy', 'clean', 'cleaner', 'cleanest', 'cleanliness', 'cleanly', 'clear', 'clear-cut', 'cleared', 'clearer', 'clears', 'clever', 'cleverly', 'cohere', 'coherence', 'coherent', 'cohesive', 'colorful', 'comely', 'comfort', 'comfortable', 'comfortably', 'comforting', 'comfy', 'commend', 'commendable', 'commendably', 'commitment', 'commodious', 'compact', 'compactly', 'compassion', 'compassionate', 'compatible', 'competitive', 'complement', ' ...

# %% [markdown]
# # Extraction done and now doing data analysis in the below cell

# %%
from textblob import TextBlob
import os
import pandas as pd
import textstat
import nltk
from nltk.tokenize import word_tokenize

# Location of the text files
folder_path = 'extracted_text'

# List of all text files in the folder
file_list = os.listdir(folder_path)

# Create an empty list to store the output data
output_data = []

# Loop through each text file in the file_list
for file_name in file_list:
    print("Text File:", file_name, "Scanned")

    # Read the contents of the text file
    with open(os.path.join(folder_path, file_name), 'r') as file:
        text = file.read()

    # Check if the text is not None or empty
    if text is not None and text.strip() != '':
        
        # Removing pre-defined stopwords
        words = text.split()
        words = [word for word in words if word.lower() not in stopwords_list]
        text = ' '.join(words)
        
        # Tokenize the text
        tokens = word_tokenize(text)

        # Remove the stop words from the tokens
        tokens = [word for word in tokens if word.lower() not in stopwords_list]
        
        # Calculate the positive score
        positive_score = 0
        for word in tokens:
            if word.lower() in master_dict["positive"]:
                positive_score += 1

        # Calculate the negative score
        negative_score = 0
        for word in tokens:
            if word.lower() in master_dict["negative"]:
                negative_score += 1
        
        # Calculate the polarity score
        polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)

        # Calculate the subjectivity score
        subjectivity_score = (positive_score + negative_score) / (len(tokens) + 0.000001)
                
        # Create a TextBlob object with the article text
        text_blob = TextBlob(text)

        # Compute the sentiment scores
        # positive_score = text_blob.sentiment.polarity
        # negative_score = 1 - positive_score
        # polarity_score = text_blob.sentiment.polarity
        # subjectivity_score = text_blob.sentiment.subjectivity

        # Compute the average sentence length
        avg_sentence_length = sum(len(sentence.words) for sentence in text_blob.sentences) / len(text_blob.sentences)

        # Compute the percentage of complex words
        complex_word_count = len([word for word in text_blob.words if len(word) >= 5])
        percentage_of_complex_words = complex_word_count / len(text_blob.words)

        # Compute the FOG index
        fog_index = 0.4 * (avg_sentence_length + percentage_of_complex_words)

        # Compute the average number of words per sentence
        avg_number_of_words_per_sentence = len(text_blob.words) / len(text_blob.sentences)

        # Compute the word count
        word_count = len(text_blob.words)

        # Compute the syllables per word
        syllables_per_word = sum(textstat.syllable_count(word) for word in text_blob.words) / len(text_blob.words)

        # Compute the personal pronouns count
        personal_pronouns = len([word for word in text_blob.words if word.lower() in ['i', 'me', 'my', 'mine', 'myself']])

        # Compute the average word length
        avg_word_length = sum(len(word) for word in text_blob.words) / len(text_blob.words)
    
        # Append the computed data to the output data list
        output_data.append([positive_score, negative_score, polarity_score, subjectivity_score,
                       avg_sentence_length, percentage_of_complex_words, fog_index, avg_number_of_words_per_sentence,
                       complex_word_count, word_count, syllables_per_word, personal_pronouns, avg_word_length])
# Out:
# Text File: 100.txt Scanned
# Text File: 101.txt Scanned
# Text File: 102.txt Scanned
# Text File: 103.txt Scanned
# Text File: 104.txt Scanned
# Text File: 105.txt Scanned
# Text File: 106.txt Scanned
# Text File: 107.txt Scanned
output_df = pd.DataFrame(output_data, columns=['POSITIVE_SCORE', 'NEGATIVE_SCORE', 'POLARITY_SCORE', 'SUBJECTIVITY_SCORE', 'AVG_SENTENCE_LENGTH', 'PERCENTAGE_OF_COMPLEX_WORDS', 'FOG_INDEX', 'AVG_NUMBER_OF_WORDS_PER_SENTENCE', 'COMPLEX_WORD_COUNT', 'WORD_COUNT', 'SYLLABLE_PER_WORD', 'PERSONAL_PRONOUNS', 'AVG_WORD_LENGTH'])
output_df.head()
# Out:
#    POSITIVE_SCORE  NEGATIVE_SCORE  POLARITY_SCORE  SUBJECTIVITY_SCORE  \
# 0              22              41       -0.301587            0.076364
# 1               4               3        0.142857            0.070707
# 2              28              46       -0.243243            0.116535
# 3               8              25       -0.515151            0.077830
# 4              28              57       -0.341176            0.128205
#
#    AVG_SENTENCE_LENGTH  PERCENTAGE_OF_COMPLEX_WORDS  FOG_INDEX  \
# 0            12.589286                     0.768794   5.343232
# 1             9.444444                     0.741176   4.074248
# 2             8.983333                     0.805195   3.915411
# 3             9.800000                     0.778426   4.231370
# 4            12.187500                     0.864957   5.220983
#
#    AVG_NUMBER_OF_WORDS_PER_SENTENCE  COMPLEX_WORD_COUNT  WORD_COUNT  \
# 0                         12.589286                 542         705
# 1                          9.444444                  63          85
# 2                          8.983333                 434         539
# 3                          9.800000                 267         343
# 4                         12.187500                 506         585
#
#    SYLLABLE_PER_WORD  PERSONAL_PRONOUNS  AVG_WORD_LENGTH
# 0           2.005674                  0         6.808511
# 1           1.764706                  0         6.282353
# 2           1.955473                  0         6.640074
# 3           1.921283                  0         6.632653
# 4           2.213675                  0         7.297436

# %% [markdown]
# # Now joining the df and output_df with each other to have the same format as of output_data_structure

# %%
df = pd.read_excel('Input.xlsx')

output_ds = pd.concat([df, output_df], axis=1)
output_ds.head()
# Out:
#    URL_ID                                                URL  POSITIVE_SCORE  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...              22
# 1      38  https://insights.blackcoffer.com/what-if-the-c...               4
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...              28
# 3      40  https://insights.blackcoffer.com/will-machine-...               8
# 4      41  https://insights.blackcoffer.com/will-ai-repla...              28
#
#    NEGATIVE_SCORE  POLARITY_SCORE  SUBJECTIVITY_SCORE  AVG_SENTENCE_LENGTH  \
# 0              41       -0.301587            0.076364            12.589286
# 1               3        0.142857            0.070707             9.444444
# 2              46       -0.243243            0.116535             8.983333
# 3              25       -0.515151            0.077830             9.800000
# 4              57       -0.341176            0.128205            12.187500
#
#    PERCENTAGE_OF_COMPLEX_WORDS  FOG_INDEX  AVG_NUMBER_OF_WORDS_PER_SENTENCE  \
# 0                     0.768794   5.343232                         12.589286
# 1                     0.741176   4.074248                          9.444444
# 2                     0.805195   3.915411                          8.983333
# 3                     0.778426   4.231370                          9.800000
# 4                     0.864957   5.220983                         12.187500
#
#    COMPLEX_WORD_COUNT  WORD_COUNT  SYLLABLE_PER_WORD  PERSONAL_PRONOUNS  \
# 0                 542         705           2.005674                  0
# 1                  63          85           1.764706                  0
# 2                 434         539           1.955473                  0
# 3                 267         343           1.921283                  0
# 4                 506         585           2.213675                  0
#
#    AVG_WORD_LENGTH
# 0         6.808511
# 1         6.282353
# 2         6.640074
# 3         6.632653
# 4         7.297436

# %% [markdown]
# # Saving the excel file locally as "Output Data Structure"

# %%
output_ds.to_excel("Output Data Structure.xlsx", index=False)
